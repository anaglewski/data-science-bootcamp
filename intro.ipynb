# %% [markdown]
# <a href="https://colab.research.google.com/github/anaglewski/data-science-bootcamp/blob/main/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
x = np.array([1,3])
x
# Out:
# array([1, 3])

# %%
print(x)
# Drukuj obiekt x
# Out:
# [1 3]

# %%
type(x)
#typ obiektu x
# Out:
# numpy.ndarray

# %%
x.ndim
# ilość wymiarów
# Out:
# 1

# %%
x.shape
# Ilość elementów oraz struktura wymiarów
# Out:
# (2,)

# %%
x.size
# Liczba elementów
# Out:
# 2

# %%
x.dtype
#Typ danych - nie zmiennej
# Out:
# dtype('int64')

# %%
y = np.array([1.3,2.3,1.4])
y
# Out:
# array([1.3, 2.3, 1.4])

# %%
y.dtype
# Out:
# dtype('float64')

# %%
x = np.array([[1,2],[-3,1]])
x
# Out:
# array([[ 1,  2],
#        [-3,  1]])

# %%
x.ndim
# Out:
# 2

# %%
x.shape
# Out:
# (2, 2)

# %%
x = np.array([[1,2,4],[4,2,1]])
print(x)
# Out:
# [[1 2 4]
#  [4 2 1]]

# %%
x.shape
# Out:
# (2, 3)

# %%
# Tablice 3D

# %%
x = np.array([[[1,1,1,0],[2,2,2,0]],
              [[3,3,3,1],[4,4,4,1]]])
x
# Out:
# array([[[1, 1, 1, 0],
#         [2, 2, 2, 0]],
#
#        [[3, 3, 3, 1],
#         [4, 4, 4, 1]]])

# %%
x.shape
# Out:
# (2, 2, 4)
